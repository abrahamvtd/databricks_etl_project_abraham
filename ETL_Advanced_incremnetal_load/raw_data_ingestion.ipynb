# %%
# %run ./initial_setup

# %%
try:
    logger.info("raw data is started to load bronze table")
    raw_data = spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .load(raw_file)
    
    raw_data.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("etl_incremental.bronze.patient_bronze")
    
    logger.info("row data is loaded to bronze table")
except Exception as e:
    logger.info("error happened during the data read")

# %%
# %sql
# select * from etl_incremental.bronze.patient_bronze
