# %%
# %sql
-- Create schema
CREATE SCHEMA IF NOT EXISTS demo_catalog.healthcare;

-- Create volume for raw data
CREATE VOLUME IF NOT EXISTS demo_catalog.healthcare.raw_volume;

# %%
df = spark.read.format("csv").option(
    "header",
    True
).load("/Volumes/demo_catalog/healthcare/raw_volume/patient_50k_records.csv")
display(df)
